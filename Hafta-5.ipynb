# %%
import pandas as pd

# %%
jb = pd.read_csv("./resources/jamesbond.csv", index_col="Film")
jb.sort_index(inplace=True)
jb
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
jb.loc["Dr. No"] 
# Elimizdeki index alanı sözel ise loc ile ulaşılır sonra indis belirtilir .
# Bir seri olarak geri döndürdü .
# Out:
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                         7.0
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
jb.loc["Casino Royale", "Actor"] 
# Bu ilgili alandaki ilgili değeri gösteriyor .
# Out:
# Film
# Casino Royale    Daniel Craig
# Casino Royale     David Niven
# Name: Actor, dtype: object

# %%
jb.loc["Dr. No", "Actor"] = "Veli Git"
jb.loc["Dr. No"]
# Bu alandaki değeri değiştirdik .
# Out:
# Year                          1962
# Actor                     Veli Git
# Director             Terence Young
# Box Office                   448.8
# Budget                         7.0
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
jb.loc["Dr. No", 
["Box Office", "Budget", "Bond Actor Salary"]] = [1, 2, 3]
jb.loc["Dr. No"]
# Birden fazla alana erişmek için liste kullanılır . Değiştirilecek değeride liste olarak vermeliyiz .
# Out:
# Year                          1962
# Actor                     Veli Git
# Director             Terence Young
# Box Office                     1.0
# Budget                         2.0
# Bond Actor Salary              3.0
# Name: Dr. No, dtype: object

# %%
jb["Actor"] == "Sean Connery"  
# Tru false şeklinde actörü sean connery olan filmleri getirir .
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia with Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again               True
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
jb["Actor"] == "Sean Connery"
jb[jb["Actor"] == "Sean Connery"]
# Filtreleme işlemi actor alanında sean connery olan kayıtları listelicek .
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
jb[jb["Actor"] == "Sean Connery"]["Director"]
# actörü sean connery  olan filmlerin yönetmenlerini listelicektir .
# Out:
# Film
# Diamonds Are Forever       Guy Hamilton
# From Russia with Love     Terence Young
# Goldfinger                 Guy Hamilton
# Never Say Never Again    Irvin Kershner
# Thunderball               Terence Young
# You Only Live Twice       Lewis Gilbert
# Name: Director, dtype: object

# %%
jb.loc[jb["Actor"] == "Sean Connery", "Director"]
#  yukarıdaki işlemle aynı görevi görür .
# Out:
# Film
# Diamonds Are Forever       Guy Hamilton
# From Russia with Love     Terence Young
# Goldfinger                 Guy Hamilton
# Never Say Never Again    Irvin Kershner
# Thunderball               Terence Young
# You Only Live Twice       Lewis Gilbert
# Name: Director, dtype: object

# %%
jb.rename(mapper={"GoldenEye": "Golden Eye",
                   "The World Is Not Enough" : "Best Bond Movie Ever"
                 })
jb.rename(mapper={"GoldenEye": "Golden Eye",
                   "The World Is Not Enough" : "Best Bond Movie Ever"
                 }, axis=0)
jb.rename(mapper={"GoldenEye": "Golden Eye",
                   "The World Is Not Enough" : "Best Bond Movie Ever"
                 }, axis="rows")
jb.rename(mapper={"GoldenEye": "Golden Eye",
                   "The World Is Not Enough" : "Best Bond Movie Ever"
                 }, axis="index")
# mapper kullanırsak tipi dictionary olmak zorunda . 
# Yukaraıdaki işlemlerin hepsi aynıdır .
# mapper kullanılarak satır isimlerinde değişiklik yaptık .
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
jb.rename(mapper={"Year":"Release Date",
                "Box Office":"Revenue"
                 }, axis=1)
jb.rename(mapper={"Year":"Release Date",
                "Box Office":"Revenue"
                 }, axis="columns")
jb.rename(columns={"Year":"Release Date",
                "Box Office":"Revenue"
                 })
# mapper kullarak sütun isminde değişiklik yaptık .
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962        Veli Git
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
jb.drop("A View to a Kill")
jb.drop(["A View to a Kill", "Die Another Day",
        "Casino Royale"])
# ilgili satırı siler  * ilşemine göre silme yapılır .
# Out:
#                                  Year           Actor            Director  \
# Film
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Dr. No                           1962        Veli Git       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# ...

# %%
jb.pop("Actor")
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                                   Veli Git
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %%
jb
# Out:
#                                  Year            Director  Box Office  Budget  \
# Film
# A View to a Kill                 1985           John Glen       275.2    54.5
# Casino Royale                    2006     Martin Campbell       581.5   145.3
# Casino Royale                    1967          Ken Hughes       315.0    85.0
# Diamonds Are Forever             1971        Guy Hamilton       442.5    34.7
# Die Another Day                  2002        Lee Tamahori       465.4   154.2
# Dr. No                           1962       Terence Young         1.0     2.0
# For Your Eyes Only               1981           John Glen       449.4    60.2
# From Russia with Love            1963       Terence Young       543.8    12.6
# GoldenEye                        1995     Martin Campbell       518.5    76.9
# Goldfinger                       1964        Guy Hamilton       820.4    18.6
# Licence to Kill                  1989           John Glen       250.9    56.7
# ...

# %%
del jb["Director"] 
jb
# Out:
#                                  Year  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                 1985       275.2    54.5                9.1
# Casino Royale                    2006       581.5   145.3                3.3
# Casino Royale                    1967       315.0    85.0                NaN
# Diamonds Are Forever             1971       442.5    34.7                5.8
# Die Another Day                  2002       465.4   154.2               17.9
# Dr. No                           1962         1.0     2.0                3.0
# For Your Eyes Only               1981       449.4    60.2                NaN
# From Russia with Love            1963       543.8    12.6                1.6
# GoldenEye                        1995       518.5    76.9                5.1
# Goldfinger                       1964       820.4    18.6                3.2
# Licence to Kill                  1989       250.9    56.7                7.9
# ...

# %%
jb = pd.read_csv("resources/jamesbond.csv", index_col="Film")
jb.sort_index(inplace=True)

# %%
s1 = jb.shape
s2 = jb.sample(frac=.5).shape
print(s1, s2)
# Out:
# (26, 6) (13, 6)

# %%
jb.sample(2, axis=1)
# tüm kayıtları getirir ama rastgele iki tane sütun seçerek .
# Out:
#                                  Year  Budget
# Film
# A View to a Kill                 1985    54.5
# Casino Royale                    2006   145.3
# Casino Royale                    1967    85.0
# Diamonds Are Forever             1971    34.7
# Die Another Day                  2002   154.2
# Dr. No                           1962     7.0
# For Your Eyes Only               1981    60.2
# From Russia with Love            1963    12.6
# GoldenEye                        1995    76.9
# Goldfinger                       1964    18.6
# Licence to Kill                  1989    56.7
# Live and Let Die                 1973    30.8
# Moonraker                        1979    91.5
# Never Say Never Again            1983    86.0
# Octopussy                        1983    53.9
# On Her Majesty's Secret Service  1969    37.3
# Quantum of Solace                2008   181.4
# Skyfall                          2012   170.2
# Spectre                          2015   206.3
# ...

# %%
jb.sort_values("Budget", ascending=False)
# Out:
#                                  Year           Actor            Director  \
# Film
# Spectre                          2015    Daniel Craig          Sam Mendes
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Casino Royale                    1967     David Niven          Ken Hughes
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# The Living Daylights             1987  Timothy Dalton           John Glen
# ...

# %%
jb.nlargest(n=3, columns="Budget")
# Budget alanındki en yüksek alana sahip 3 alanı getir .
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
jb.nsmallest(n=5, columns="Budget")
# Budget alanındaki en düşük 5 değeri getir .
# Out:
#                              Year         Actor       Director  Box Office  \
# Film
# Dr. No                       1962  Sean Connery  Terence Young       448.8
# From Russia with Love        1963  Sean Connery  Terence Young       543.8
# Goldfinger                   1964  Sean Connery   Guy Hamilton       820.4
# The Man with the Golden Gun  1974   Roger Moore   Guy Hamilton       334.0
# Live and Let Die             1973   Roger Moore   Guy Hamilton       460.3
#
#                              Budget  Bond Actor Salary
# Film
# Dr. No                          7.0                0.6
# From Russia with Love          12.6                1.6
# Goldfinger                     18.6                3.2
# The Man with the Golden Gun    27.7                NaN
# Live and Let Die               30.8                NaN

# %%
jb.where(jb["Actor"] ==  "Sean Connery")
# Aktör alanında sean connery olanları getiriyor fakat bu şartı sağlamayan değerleride nan olark getiriyor .
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
jb.where((jb["Actor"] ==  "Sean Connery") & (jb.Budget > 80))
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever                NaN           NaN             NaN
# Die Another Day                     NaN           NaN             NaN
# Dr. No                              NaN           NaN             NaN
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love               NaN           NaN             NaN
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                          NaN           NaN             NaN
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
jb.columns
# columns isimlerindeki sıkıntı arasında boşluk var .
# Out:
# Index(['Year', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
[column.replace(" ", "_") for column in jb.columns]

# Bütün column isimlerini for ile geziyorum bütün boşluk olanları _ ile değiştiriyorum .
# Out:
# ['Year', 'Actor', 'Director', 'Box_Office', 'Budget', 'Bond_Actor_Salary']

# %%
jb.columns = [column.replace(" ", "_") for column in jb.columns]
jb
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
jb.query('Actor == "Sean Connery" and Budget > 80')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
#
#                        Bond_Actor_Salary
# Film
# Never Say Never Again                NaN

# %%
def add_suffix(number):
    return str(number) + "Million $"
# Out:
# 16

# %%
jb["Budget"] = jb["Budget"].apply(add_suffix)
jb
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
jb = pd.read_csv("resources/jamesbond.csv", index_col="Film")
jb.sort_index(inplace=True)

# %%
def degerlendir(row):
    aktor = row.iloc[1]
    butce = row.iloc[4]

    if aktor == "Pierce Brosnan":
        return "En İyi"
    elif aktor == "Roger Moore" and butce > 40:
        return "Eğlenceli"
    else:
        return "Fikrim Yok"
    
 # fonksiyonu yazdık sonra actor ve butce satırlarını seçtik sonra if le şartlarımızı yazıp geri ne döndüreceğini yazdırdık .

# %%
jb.apply(degerlendir, axis=1)
# Out:
# Film
# A View to a Kill                    Eğlenceli
# Casino Royale                      Fikrim Yok
# Casino Royale                      Fikrim Yok
# Diamonds Are Forever               Fikrim Yok
# Die Another Day                        En İyi
# Dr. No                             Fikrim Yok
# For Your Eyes Only                  Eğlenceli
# From Russia with Love              Fikrim Yok
# GoldenEye                              En İyi
# Goldfinger                         Fikrim Yok
# Licence to Kill                    Fikrim Yok
# Live and Let Die                   Fikrim Yok
# Moonraker                           Eğlenceli
# Never Say Never Again              Fikrim Yok
# Octopussy                           Eğlenceli
# On Her Majesty's Secret Service    Fikrim Yok
# Quantum of Solace                  Fikrim Yok
# Skyfall                            Fikrim Yok
# Spectre                            Fikrim Yok
# The Living Daylights               Fikrim Yok
# ...

# %%
import random

def test(dataframe, n=None, replace=False, random_state=None):
    if n is None:
        n = 1
    if n > len(dataframe):
        raise ValueError("n cannot be greater than the dataframe size.")
    
    if random_state is not None:
        random.seed(random_state)
    
    if replace:
        indices = random.choices(range(len(dataframe)), k=n)
    else:w
        indices = random.sample(range(len(dataframe)), k=n)
    
    return dataframe.iloc[indices]

jb = pd.read_csv("resources/jamesbond.csv", index_col="Film")

test(jb, n=2)
# Out:
#                       Year           Actor       Director  Box Office  Budget  \
# Film
# The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0    45.1
# The Living Daylights  1987  Timothy Dalton      John Glen       313.5    68.8
#
#                       Bond Actor Salary
# Film
# The Spy Who Loved Me                NaN
# The Living Daylights                5.2
