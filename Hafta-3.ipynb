# %%
import pandas as pd

# %%
df_emp = pd.read_csv("./resources/employees.csv")
df_emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df_emp.describe().T # describe(), DataFrame'in temel istatistiksel özetini oluşturur. Bu özet, count (sayım),
# mean (ortalama), std (standart sapma), min (minimum değer), 25% (1. çeyrek),
# 50% (2. çeyrek veya medyan), 75% (3. çeyrek) ve max (maksimum değer)
# gibi temel istatistiksel değerleri içerir. T transpozunu alır(satırla sütun yer değiştirir)
# Out:
#           count          mean           std        min          25%  \
# Salary   1000.0  90662.181000  32923.693342  35013.000  62613.00000
# Bonus %  1000.0     10.207555      5.528481      1.015      5.40175
#
#                 50%         75%         max
# Salary   90428.0000  118740.250  149908.000
# Bonus %      9.8385      14.838      19.944

# %%
df_emp.columns # sütun indexlerini temsil eden bir index nesnesi döndürür.
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df_emp["First Name"] # seri : tek sütundan  oluşan nesnelerden first name i getirdi.  (seri döndürür)
# Out:
# 0      Douglas
# 1       Thomas
# 2        Maria
# 3        Jerry
# 4        Larry
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: First Name, Length: 1000, dtype: object

# %%
df_emp.Salary
# Out:
# 0       97308
# 1       61933
# 2      130590
# 3      138705
# 4      101004
#         ...
# 995    132483
# 996     42392
# 997     96914
# 998     60500
# 999    129949
# Name: Salary, Length: 1000, dtype: int64

# %%
df_emp[["First Name" , "Salary"]] # tek sütun varsa seri birden fazla sütun varsa dataframe elde edilir.
# Out:
#     First Name  Salary
# 0      Douglas   97308
# 1       Thomas   61933
# 2        Maria  130590
# 3        Jerry  138705
# 4        Larry  101004
# ..         ...     ...
# 995      Henry  132483
# 996    Phillip   42392
# 997    Russell   96914
# 998      Larry   60500
# 999     Albert  129949
#
# [1000 rows x 2 columns]

# %%
df_emp.Salary.sum()  # toplamını verir . İstediğimiz matematiksel işlemleri yapabiliriz .
# Out:
# 90662181

# %%
revenue = pd.read_csv("./resources/revenue.csv" , index_col="Date")
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
revenue.sum()       # sütun bazında toplam alır
revenue.sum(axis=0)  
revenue.sum(axis="index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis=1)  # satır bazında toplam alır
revenue.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba = pd.read_csv("./resources/nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
selected_columns = ["Name" , "Team" , "Age"]  
nba[selected_columns] # bu kod bloğu, "Name", "Team" ve "Age" sütunlarını içeren 
                      # bir alt DataFrame'i seçmeye çalışıyor.
# Out:
#               Name            Team   Age
# 0    Avery Bradley  Boston Celtics  25.0
# 1      Jae Crowder  Boston Celtics  25.0
# 2     John Holland  Boston Celtics  27.0
# 3      R.J. Hunter  Boston Celtics  22.0
# 4    Jonas Jerebko  Boston Celtics  29.0
# ..             ...             ...   ...
# 453   Shelvin Mack       Utah Jazz  26.0
# 454      Raul Neto       Utah Jazz  24.0
# 455   Tibor Pleiss       Utah Jazz  26.0
# 456    Jeff Withey       Utah Jazz  26.0
# 457            NaN             NaN   NaN
#
# [458 rows x 3 columns]

# %%
nba ["Sports"] = "Basketball"   # Burada olmayan bir column eklemek için kullanılır
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary      Sports
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba.insert(loc=3 ,column="Sport" ,value="Basketball") 
nba.head() # dataframe e insertle 3. column a  sport adında değeri basketball olan bir veri ekleniyor
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#    Weight            College     Salary      Sports
# 0   180.0              Texas  7730337.0  Basketball
# 1   235.0          Marquette  6796117.0  Basketball
# 2   205.0  Boston University        NaN  Basketball
# 3   185.0      Georgia State  1148640.0  Basketball
# 4   231.0                NaN  5000000.0  Basketball

# %%
nba["New_Age"] = nba["Age"] + 10  # önce yeni bir column oluşturduk  sonra nba oyuncularının yaşlarına 10 ekledik 
nba.head()
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#    Weight            College     Salary      Sports  New_Age
# 0   180.0              Texas  7730337.0  Basketball     35.0
# 1   235.0          Marquette  6796117.0  Basketball     35.0
# 2   205.0  Boston University        NaN  Basketball     37.0
# 3   185.0      Georgia State  1148640.0  Basketball     32.0
# 4   231.0                NaN  5000000.0  Basketball     39.0

# %%
nba["Weight (Kg)"] = nba["Weight"].mul(0.435)  # normalde orada başka bir ölçü birimi var.
nba.head() # weihht (kg) adında yeni column oluşturduk weighti öul metodyla çarparak kiloya çevirdik
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#    Weight            College     Salary      Sports  Weight (Kg)
# 0   180.0              Texas  7730337.0  Basketball       78.300
# 1   235.0          Marquette  6796117.0  Basketball      102.225
# 2   205.0  Boston University        NaN  Basketball       89.175
# 3   185.0      Georgia State  1148640.0  Basketball       80.475
# 4   231.0                NaN  5000000.0  Basketball      100.485

# %%
nba = pd.read_csv("./resources/nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.drop(labels=["New_Age" ,"Salary"] , axis=1 , inplace = True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nba.drop(labels=["New_Age" ,"Salary"] , axis=1 , inplace = True )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
nba.Team.value_counts()  # sql deki  group by ın yaptığı işi yapar (içindeki her benzersiz değerin)
#(kaç kez sıralandığını verir.)
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
nba.dropna() # Dataframe  içinde Nan geçen satırları siler.
# Out:
#               Name            Team  Number       Sport Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 3      R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 6    Jordan Mickey  Boston Celtics    55.0  Basketball       PF  21.0    6-8
# 7     Kelly Olynyk  Boston Celtics    41.0  Basketball        C  25.0    7-0
# ..             ...             ...     ...         ...      ...   ...    ...
# 449    Rodney Hood       Utah Jazz     5.0  Basketball       SG  23.0    6-8
# 451  Chris Johnson       Utah Jazz    23.0  Basketball       SF  26.0    6-6
# 452     Trey Lyles       Utah Jazz    41.0  Basketball       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0  Basketball       PG  26.0    6-3
# 456    Jeff Withey       Utah Jazz    24.0  Basketball        C  26.0    7-0
#
# ...

# %%
nba.dropna(inplace=True) # içinde nan geçen satırları kalıcı olarak siler

# %%
nba.drop(["Sport" , "New_Age" , "Weight  (Kg)"] , axis=1 , inplace=True)
nba
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nba.drop(["Sport" , "New_Age" , "Weight  (Kg)"] , axis=1 , inplace=True)
#       2 nba
#
# NameError: name 'nba' is not defined

# %%
nba.dropna(how="all")  # bütün alanlardaki Nan olan değerlerin kayıtlarını siler
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.dropna(subset=["College"]) # belli bir sütun üzerinde işlem yapmak istiyorum subset (burda college)
#  belirli bir satırdaki  Nan değerleri siliyor
# Out:
#               Name            Team  Number       Sport Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 6    Jordan Mickey  Boston Celtics    55.0  Basketball       PF  21.0    6-8
# ..             ...             ...     ...         ...      ...   ...    ...
# 449    Rodney Hood       Utah Jazz     5.0  Basketball       SG  23.0    6-8
# 451  Chris Johnson       Utah Jazz    23.0  Basketball       SF  26.0    6-6
# 452     Trey Lyles       Utah Jazz    41.0  Basketball       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0  Basketball       PG  26.0    6-3
# 456    Jeff Withey       Utah Jazz    24.0  Basketball        C  26.0    7-0
#
# ...

# %%
nba.fillna(0) # Dataframe deki eksik yerleri ne ile dolduracağımızı belirtir. Burada (0) vermiş.
# Out:
#               Name            Team  Number       Sport Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
# ..             ...             ...     ...         ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0  Basketball       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Basketball       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Basketball        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Basketball        C  26.0    7-0
# 457              0               0     0.0  Basketball        0   0.0      0
#
# ...

# %%
nba["College"].fillna("Boş") # Seri üzerindede doldurmayı yapabiliriz.
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                    Boş
#              ...
# 453               Butler
# 454                  Boş
# 455                  Boş
# 456               Kansas
# 457                  Boş
# Name: College, Length: 458, dtype: object

# %%
 nba.dtypes  # Her sütunun veri tipini döndürür.
# Out:
# Name            object
# Team            object
# Number         float64
# Sport           object
# Position        object
# Age            float64
# Height          object
# Weight         float64
# College         object
# Sports          object
# Weight (Kg)    float64
# dtype: object

# %%
nba.Age.hasnans # Bir seri içerisinde Nan değer olup olmadığına bakar .
# Out:
# True

# %%
nba.Number.hasnans
# Out:
# True

# %%
nba.dropna(subset=["Age"], inplace=True)
nba.Age.hasnans
# Out:
# False

# %%
nba.Age.astype("int")
nba.Age.astype(int) 
 # Veri tipi dönüşümü yapmamızı sağlar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nba.Age.astype("int")
#       2 nba.Age.astype(int)
#
# NameError: name 'nba' is not defined

# %%
nba.Age.astype("int")
nba["Age"] = nba.Age.astype(int)
nba.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nba.Age.astype("int")
#       2 nba["Age"] = nba.Age.astype(int)
#       3 nba.dtypes
#
# NameError: name 'nba' is not defined

# %%
nba["Position"].unique()   # kaç farklı değer içerdiğini görüyoruz
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 457 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         457 non-null    object
#  1   Team         457 non-null    object
#  2   Number       457 non-null    float64
#  3   Sport        457 non-null    object
#  4   Position     457 non-null    object
#  5   Age          457 non-null    float64
#  6   Height       457 non-null    object
#  7   Weight       457 non-null    float64
#  8   College      373 non-null    object
#  9   Sports       457 non-null    object
#  10  Weight (Kg)  457 non-null    float64
# dtypes: float64(4), object(7)
# memory usage: 42.8+ KB

# %%
nba["Position"] = nba["Position"].astype("category") #bellekte kaplandığı alanı düşürmüş olduk
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 457 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         457 non-null    object
#  1   Team         457 non-null    object
#  2   Number       457 non-null    float64
#  3   Sport        457 non-null    object
#  4   Position     457 non-null    category
#  5   Age          457 non-null    float64
#  6   Height       457 non-null    object
#  7   Weight       457 non-null    float64
#  8   College      373 non-null    object
#  9   Sports       457 non-null    object
#  10  Weight (Kg)  457 non-null    float64
# dtypes: category(1), float64(4), object(6)
# memory usage: 39.9+ KB

# %%
nba.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
nba.Team.nunique()
# Out:
# 30

# %%
nba.sort_values()    # istediğiniz alana göre sıralama yapabilirsiniz.

# %%
nba.sort_values(by = "Name")  # name alanına göre kayıtları sıraladı.
# Out:
#                 Name                    Team  Number       Sport Position  \
# 152     Aaron Brooks           Chicago Bulls     0.0  Basketball       PG
# 356     Aaron Gordon           Orlando Magic     0.0  Basketball       PF
# 328   Aaron Harrison       Charlotte Hornets     9.0  Basketball       SG
# 404    Adreian Payne  Minnesota Timberwolves    33.0  Basketball       PF
# 312       Al Horford           Atlanta Hawks    15.0  Basketball        C
# ..               ...                     ...     ...         ...      ...
# 386  Wilson Chandler          Denver Nuggets    21.0  Basketball       SF
# 270   Xavier Munford       Memphis Grizzlies    14.0  Basketball       PG
# 402      Zach LaVine  Minnesota Timberwolves     8.0  Basketball       PG
# 271    Zach Randolph       Memphis Grizzlies    50.0  Basketball       PF
# 237    Zaza Pachulia        Dallas Mavericks    27.0  Basketball        C
#
#       Age Height  Weight         College      Sports  Weight (Kg)
# ...

# %%
nba.sort_values(by = "College" , na_position="first") #college alanına göre sıralama yap na yaanları başta göster
# Out:
#                        Name                Team  Number       Sport Position  \
# 4             Jonas Jerebko      Boston Celtics     8.0  Basketball       PF
# 5              Amir Johnson      Boston Celtics    90.0  Basketball       PF
# 15         Bojan Bogdanovic       Brooklyn Nets    44.0  Basketball       SG
# 20           Sergey Karasev       Brooklyn Nets    10.0  Basketball       SG
# 32   Thanasis Antetokounmpo     New York Knicks    43.0  Basketball       SF
# ..                      ...                 ...     ...         ...      ...
# 331      Frank Kaminsky III   Charlotte Hornets    44.0  Basketball        C
# 129               Jon Leuer        Phoenix Suns    30.0  Basketball       PF
# 247              Sam Dekker     Houston Rockets     7.0  Basketball       SF
# 114         Larry Nance Jr.  Los Angeles Lakers     7.0  Basketball       PF
# 308              David West   San Antonio Spurs    30.0  Basketball       PF
#
# ...

# %%
nba.sort_values(by =[ "College" , "Name"]) # college a göre sırala sonra college değerine sahip olanları Name e  göre sırala
# Out:
#                Name                   Team  Number       Sport Position   Age  \
# 287      Alonzo Gee   New Orleans Pelicans    15.0  Basketball       SF  29.0
# 266  JaMychal Green      Memphis Grizzlies     0.0  Basketball       PF  25.0
# 180     Mo Williams    Cleveland Cavaliers    52.0  Basketball       PG  33.0
# 356    Aaron Gordon          Orlando Magic     0.0  Basketball       PF  20.0
# 83   Andre Iguodala  Golden State Warriors     9.0  Basketball       SF  32.0
# ..              ...                    ...     ...         ...      ...   ...
# 176  Timofey Mozgov    Cleveland Cavaliers    20.0  Basketball        C  29.0
# 306     Tony Parker      San Antonio Spurs     9.0  Basketball       PG  34.0
# 124  Tyson Chandler           Phoenix Suns     4.0  Basketball        C  33.0
# 322  Walter Tavares          Atlanta Hawks    22.0  Basketball        C  24.0
# 237   Zaza Pachulia       Dallas Mavericks    27.0  Basketball        C  32.0
#
# ...

# %%
nba.sort_values(by =[ "College" , "Name"] , ascending=[True , False]) # azdan çoka sıralıyor true ise
# Out:
#                   Name                   Team  Number       Sport Position  \
# 180        Mo Williams    Cleveland Cavaliers    52.0  Basketball       PG
# 266     JaMychal Green      Memphis Grizzlies     0.0  Basketball       PF
# 287         Alonzo Gee   New Orleans Pelicans    15.0  Basketball       SF
# 54      T.J. McConnell     Philadelphia 76ers    12.0  Basketball       PG
# 192    Stanley Johnson        Detroit Pistons     3.0  Basketball       SF
# ..                 ...                    ...     ...         ...      ...
# 90    Anderson Varejao  Golden State Warriors    18.0  Basketball       PF
# 5         Amir Johnson         Boston Celtics    90.0  Basketball       PF
# 348  Amar'e Stoudemire             Miami Heat     5.0  Basketball       PF
# 275      Alexis Ajinca   New Orleans Pelicans    42.0  Basketball        C
# 330       Al Jefferson      Charlotte Hornets    25.0  Basketball        C
#
#       Age Height  Weight  College      Sports  Weight (Kg)
# ...

# %%
nba.sort_index() # default olarak indexe göre sıralama yapıyor
# Out:
#               Name            Team  Number       Sport Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
# ..             ...             ...     ...         ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0  Basketball       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0  Basketball       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Basketball       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Basketball        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Basketball        C  26.0    7-0
#
# ...

# %%
nba.sort_index(ascending=False) # sondan başa sıralama yapıyor.
# Out:
#               Name            Team  Number       Sport Position   Age Height  \
# 456    Jeff Withey       Utah Jazz    24.0  Basketball        C  26.0    7-0
# 455   Tibor Pleiss       Utah Jazz    21.0  Basketball        C  26.0    7-3
# 454      Raul Neto       Utah Jazz    25.0  Basketball       PG  24.0    6-1
# 453   Shelvin Mack       Utah Jazz     8.0  Basketball       PG  26.0    6-3
# 452     Trey Lyles       Utah Jazz    41.0  Basketball       PF  20.0   6-10
# ..             ...             ...     ...         ...      ...   ...    ...
# 4    Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
# 3      R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 2     John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 1      Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 0    Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
#
# ...

# %%
nba["Age"].fillna(0, inplace=True)
nba
# Out:
#               Name            Team  Number       Sport Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
# ..             ...             ...     ...         ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0  Basketball       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0  Basketball       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0  Basketball       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0  Basketball        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0  Basketball        C  26.0    7-0
#
# ...

# %%
nba = pd.read_csv("./resources/nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba["Salary"].fillna(0, inplace=True)
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba["Salary"].rank() # verilerimizi istediğimiz alana göre sıralayıp kaçıncı veri olduğunu gösteriyor
# Out:
# 0      362.0
# 1      349.0
# 2        6.5
# 3      137.0
# 4      312.0
#        ...
# 453    218.0
# 454     76.0
# 455    244.5
# 456     92.0
# 457      6.5
# Name: Salary, Length: 458, dtype: float64

# %%
nba["Salary_Rank"] = nba["Salary"].rank(ascending=False).astype(int)
nba
# salary lerini büyükten küçüğe sıraladım int veri tipine çevirdim
# kişiler içinde sen kaçıncı yüksek maaşı aldığını öğrendimn
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Salary_Rank
# ...

# %%
emp = pd.read_csv("./resources/employees.csv")
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
emp["Start Date"] = pd.to_datetime(emp["Start Date"])  # tür dönüşümü yaptık object olan veri tipini date time yaptık
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
emp["Last Login Time"] = pd.to_datetime(emp["Last Login Time"])
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB
# C:\Users\aktug\AppData\Local\Temp\ipykernel_11960\4190472376.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
emp["Senior Management"] = emp["Senior Management"].astype(bool)
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
emp["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
emp["Gender"] = emp["Gender"].astype("category")
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
emp_new = pd.read_csv("./resources/resources/employees.csv" , parse_dates=["Start Date" , "Last Login Time"])
emp_new["Senior Management"] = emp_new["Senior Management"].astype(bool)
emp_new["Gender"] = emp_new["Gender"].astype("category")
# Out:
# C:\Users\aktug\AppData\Local\Temp\ipykernel_11960\4009501748.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   emp_new = pd.read_csv("./resources/resources/employees.csv" , parse_dates=["Start Date" , "Last Login Time"])

# %%
emp_new[emp_new["Gender"] == "Female"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2023-10-23 11:17:00  130590   11.858
# 6         Ruby  Female 1987-08-17 2023-10-23 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2023-10-23 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2023-10-23 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2023-10-23 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2023-10-23 05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05 2023-10-23 09:34:00   47638   11.209
# 990      Robin  Female 1987-07-24 2023-10-23 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2023-10-23 05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15 2023-10-23 15:53:00   56450   19.040
#
#      Senior Management                  Team
# 2                False               Finance
# ...
