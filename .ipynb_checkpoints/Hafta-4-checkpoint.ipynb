# %%
import pandas as pd

# %%
emp = pd.read_csv("./resources/employees.csv"  ,parse_dates = ["Start Date"])
emp.info()
# parse_dates kullanarak start date sütununun içeriğini tarih olarak dönüştürdük
# önceden object idi.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
emp["Last Login Time"] = pd.to_datetime(emp["Last Login Time"])
emp.info()
# pd.to_datetime fonksiyonu bir seriyi tarih ve saat nesnesine dönüştürür.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB
# C:\Users\aktug\AppData\Local\Temp\ipykernel_7728\4190472376.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
emp.head() # yukardan ilk 5 listeyi getirir.
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp["Senior Management"] = emp["Senior Management"].astype(bool) 
emp.info()
# astype burada istenilen sütunun veri tipini değiştirmede kullanılır.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
emp.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
emp.Gender.unique()
# gender sütunundaki benzersiz değerleri döndürür.
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
emp.Gender = emp.Gender.astype("category")
emp.info()
# burada Gender sütunundaki değerlerin veri tipini "category" olarak değiştirir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
emp.Team.unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
emp
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2023-10-31 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[emp.Gender == "Female"] 
# emp nin içinde emp.Gender a erişim sağladık sonra bu 
# sütundaki female olan değerleri getirdik
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 6         Ruby  Female 1987-08-17 2023-10-31 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2023-10-31 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2023-10-31 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2023-10-31 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2023-10-31 05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05 2023-10-31 09:34:00   47638   11.209
# 990      Robin  Female 1987-07-24 2023-10-31 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2023-10-31 05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15 2023-10-31 15:53:00   56450   19.040
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp.Team.unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
emp[emp.Team == "Business Development"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 9      Frances  Female 2002-08-08 2023-10-31 06:51:00  139852    7.524
# 33        Jean  Female 1993-12-18 2023-10-31 09:07:00  119082   16.180
# 36      Rachel  Female 2009-02-16 2023-10-31 20:47:00  142032   12.599
# 38   Stephanie  Female 1986-09-13 2023-10-31 01:52:00   36844    5.574
# 41   Christine     NaN 2015-06-28 2023-10-31 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 959     Albert    Male 1992-09-19 2023-10-31 02:35:00   45094    5.850
# 960    Stephen    Male 1989-10-29 2023-10-31 23:34:00   93997   18.093
# 971    Patrick    Male 2002-12-30 2023-10-31 02:01:00   75423    5.368
# 973    Russell    Male 2013-05-10 2023-10-31 23:08:00  137359   11.105
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 9                 True  Business Development
# ...

# %%
emp[emp["Senior Management"]] #  emp[emp["Senior Management"]] == True
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2023-10-31 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2023-10-31 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2023-10-31 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2023-10-31 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2023-10-31 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp[emp.Team != "Finance"]
# Finans alanında çalışmayan Team leri gösteririr
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2023-10-31 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2023-10-31 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[emp.Salary > 70000]
# salarysi(maaşı) 70 bin dolardan fazla  alanları bana listele
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2023-10-31 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2023-10-31 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp[emp["Start Date"] > "1993-01-01"] # bu tarihten sonra işe başlayanları listele
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2023-10-31 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[(emp.Team == "Finance") & (emp.Gender == "Male")] 
# Finance grubunda çalışan  VE  erkekleri getir
# Out:
#       First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 3          Jerry   Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 46         Bruce   Male 2009-11-28 2023-10-31 22:47:00  114796    6.796
# 56          Carl   Male 2006-05-03 2023-10-31 17:55:00  130276   16.084
# 68          Jose   Male 2004-10-30 2023-10-31 13:39:00   84834   14.330
# 83         Shawn   Male 2005-09-23 2023-10-31 02:55:00  148115    6.539
# 117       Steven   Male 1995-03-01 2023-10-31 15:03:00  109095    9.494
# 200         Gary   Male 1987-08-12 2023-10-31 00:04:00   89661    8.525
# 205      Brandon   Male 2006-03-27 2023-10-31 17:54:00  115711    8.012
# 219        Billy   Male 1995-03-13 2023-10-31 12:05:00  120444    7.768
# 222        Jason   Male 1999-10-17 2023-10-31 22:09:00   78417    3.067
# 241       Walter   Male 1983-07-06 2023-10-31 23:54:00  127813    5.961
# 286         Todd   Male 1984-02-02 2023-10-31 10:13:00   69989   10.985
# ...

# %%
emp[(emp["Senior Management"]) | (emp["Start Date"] > "1993-01-01")]
# "Senior Management" sütununda değeri True olan veya "Start Date" sütunundaki
# değeri "1993-01-01" tarihinden sonra olan satırları getir .
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2023-10-31 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
filter1 = emp["First Name"] == "Robert"
filter2 = emp.Team == "Client Services"
filter3 = emp["Start Date"] > "2016-06-01"


emp[ (filter1 & filter2 ) | filter3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2023-10-31 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2023-10-31 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2023-10-31 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2023-10-31 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
fltr1 = emp.Team == "Legal"
fltr2 = emp.Team == "Sales"
fltr3 = emp.Team == "Product"


emp[fltr1 | fltr2 | fltr3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2023-10-31 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2023-10-31 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2023-10-31 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2023-10-31 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2023-10-31 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2023-10-31 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2023-10-31 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %%
emp[emp.Team.isin(["Sales" , "Legal" , "Product"])]
#Team sütununda değerleri sales, legal, product olanları listeler
# isin ise Team sütununda bu değerlerin olup olmadığını kontrol eder
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2023-10-30 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2023-10-30 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2023-10-30 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2023-10-30 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2023-10-30 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2023-10-30 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2023-10-30 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2023-10-30 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2023-10-30 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2023-10-30 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %%
emp[emp.Team.isnull()]
# team alanında null (NaN) içeren kayıtları getirir.
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2023-10-31 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2023-10-31 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2023-10-31 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2023-10-31 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2023-10-31 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2023-10-31 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2023-10-31 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2023-10-31 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2023-10-31 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2023-10-31 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2023-10-31 06:06:00   66067   10.957
# ...

# %%
emp[emp.Team.notnull()] 
# null(NaN) olmayan değerleri getir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2023-10-31 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[~emp.Team.isnull()] 
# not null ile aynı işi yapar
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2023-10-31 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp[(emp.Salary >= 100000) & (emp.Salary <= 150000)]
# Salary sütunundaki 100 ile 150 bin arasındaki maaşları getir.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2023-10-31 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2023-10-31 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2023-10-31 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2023-10-31 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp[emp.Salary.between(100000 , 150000)]
#Salary sütunundaki bu İki değer arasındaki değerleri getirir.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2023-10-31 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2023-10-31 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2023-10-31 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2023-10-31 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp[emp["Start Date"].between("1991-01-01" , "1992-01-01")]
# Start Date sütunundaki bu iki tarih arasındaki kayıtları getirir.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2023-10-31 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2023-10-31 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2023-10-31 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2023-10-31 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2023-10-31 02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09 2023-10-31 18:52:00   42341    7.014
# 172       Sara  Female 1991-09-23 2023-10-31 18:17:00   97058    9.402
# 220        NaN  Female 1991-06-17 2023-10-31 12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11 2023-10-31 07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29 2023-10-31 06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01 2023-10-31 02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19 2023-10-31 02:54:00   76076    5.319
# ...

# %%
emp[emp["Last Login Time"].between("08:00 AM" , "12:00 PM")]
# last login sütunundaki saat 8 ile 12 arasındaki kayıtları getirir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2023-10-31 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2023-10-31 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2023-10-31 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2023-10-31 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2023-10-31 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2023-10-31 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2023-10-31 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2023-10-31 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2023-10-31 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp[emp["First Name"].duplicated()].sort_values(by="First Name")
#  emp["First Name"].duplicated(): Bu ifade, "First Name" sütunundaki her bir
# değerin tekrar edilip edilmediğini kontrol eder.
# .sort_values(by="First Name"): Bu metot, belirtilen sütuna göre DataFrame'i
# sıralar. Bu durumda, "First Name" sütununa göre sıralama yapılır.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2023-10-31 18:48:00   58755    5.097
# 937      Aaron     NaN 1986-01-22 2023-10-31 19:39:00   63126   18.424
# 440      Aaron    Male 1990-07-22 2023-10-31 14:53:00   52119   11.343
# 538       Adam    Male 2010-10-08 2023-10-31 21:53:00   45181    3.491
# 141       Adam    Male 1990-12-24 2023-10-31 20:57:00  110194   14.727
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2023-10-31 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2023-10-31 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2023-10-31 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2023-10-31 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2023-10-31 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
emp_temp = emp.sort_values(by ="First Name")
emp_temp
# emp_temp değişkeni artık first name sütununa göre sıralanmış bir kopya içerir
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2023-10-31 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2023-10-31 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2023-10-31 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2023-10-31 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2023-10-31 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2023-10-31 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2023-10-31 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2023-10-31 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2023-10-31 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2023-10-31 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
emp_temp["First Name"].duplicated(keep=False) 
# Bir serideki herbir değerin tekrar edip edilmediğini kontrol eder 
# keep=False parametresi, tüm tekrar eden değerleri işaretler
# ve her bir tekrar eden değeri True olarak işaretler.
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
#        ...
# 902    True
# 925    True
# 946    True
# 947    True
# 951    True
# Name: First Name, Length: 1000, dtype: bool

# %%
emp[~emp["First Name"].duplicated(keep=False)]
# Bu ifade, "First Name" sütunundaki tekrar eden değerlere sahip 
# satırların dışındaki satırları seçer.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22 2023-10-31 06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18 2023-10-31 09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19 2023-10-31 03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11 2023-10-31 10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24 2023-10-31 10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07 2023-10-31 22:47:00   93901   17.821
# 832      Keith    Male 2003-02-12 2023-10-31 15:02:00  120672   19.467
# 887      David    Male 2009-12-05 2023-10-31 08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# ...

# %%
emp.shape # satır ve sütun sayısını verir
# Out:
# (1000, 8)

# %%
emp.drop_duplicates()
# drop_duplicates() bu metot dataframedeki tekrar eden satırları kaldırır.
# orjinal veri seti korunur ve temizlenmiş bir kopya oluşturur.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2023-10-31 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2023-10-31 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
emp.drop_duplicates(subset="First Name", keep=False)
# "First Name" sütunundaki değerlere göre tekrar eden satırları kaldırır ve 
# temizlenmiş bir DataFrame döndürür.
#subset dataframe üzerindeki bir sütunu yada sütunları seçmek için kullanılır.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2023-10-31 01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22 2023-10-31 06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18 2023-10-31 09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19 2023-10-31 03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11 2023-10-31 10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24 2023-10-31 10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07 2023-10-31 22:47:00   93901   17.821
# 832      Keith    Male 2003-02-12 2023-10-31 15:02:00  120672   19.467
# 887      David    Male 2009-12-05 2023-10-31 08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# ...

# %%
emp.drop_duplicates(subset = ["First Name" , "Team"])
#  first name ve team sütunundaki tekrar eden değerleri kaldırdı
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2023-10-31 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2023-10-31 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2023-10-31 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2023-10-31 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2023-10-31 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2023-10-31 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2023-10-31 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2023-10-31 06:30:00   42392   19.675
# 998      Larry    Male 2013-04-20 2023-10-31 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2023-10-31 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
james_bond = pd.read_csv("./resources/jamesbond.csv" ) 
james_bond
# film columunu index yaptı ( index_col="Film" )
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
james_bond.set_index("Film" , inplace = True)
james_bond
# Film sütunu dataframe e index olarak atandı ve kalıcı olarak
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
james_bond.reset_index(drop=True)
# reset index : dataframein indeksini sıfırlar . 
# drop true : eski indexin yeni dataframe e eklenmemesini belirtir
# sonuç olarak dataframe indexi sıfırlar.
# Out:
#     Year           Actor            Director  Box Office  Budget  \
# 0   1962    Sean Connery       Terence Young       448.8     7.0
# 1   1963    Sean Connery       Terence Young       543.8    12.6
# 2   1964    Sean Connery        Guy Hamilton       820.4    18.6
# 3   1965    Sean Connery       Terence Young       848.1    41.9
# 4   1967     David Niven          Ken Hughes       315.0    85.0
# 5   1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 6   1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 7   1971    Sean Connery        Guy Hamilton       442.5    34.7
# 8   1973     Roger Moore        Guy Hamilton       460.3    30.8
# 9   1974     Roger Moore        Guy Hamilton       334.0    27.7
# 10  1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 11  1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 12  1981     Roger Moore           John Glen       449.4    60.2
# ...

# %%
james_bond.reset_index(inplace=True)
james_bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
james_bond.sort_values(by="Year")
james_bond
# Dataframe in Year sütununa göre sıralanmasını gerçekleştirir
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
james_bond.set_index("Year" , verify_integrity=True)
james_bond
# burada year sütunun index olarak ayarlamaya çalışıyor fakat 
# verify_integrity=True parametresi sadece benzersiz durumda geçerli.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7728\2957835872.py in ?()
# ----> 1 james_bond.set_index("Year" , verify_integrity=True)
#       2 james_bond
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5915         index = ensure_index_from_sequences(arrays, names)
#    5916
#    5917         if verify_integrity and not index.is_unique:
#    5918             duplicates = index[index.duplicated()].unique()
# -> 5919             raise ValueError(f"Index has duplicate keys: {duplicates}")
#    5920
#    5921         # use set to handle duplicate column names gracefully in case of drop
#    5922         for c in set(to_remove):
#
# ValueError: Index has duplicate keys: Index([1967, 1983], dtype='int64', name='Year')

# %%
james_bond = pd.read_csv("./resources/jamesbond.csv" )
james_bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
james_bond.set_index("Film" , inplace=True)
james_bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
james_bond.loc["Die Another Day"]
# .loc["Die Another Day"] bu ifade index etiketi "Die Another Day"  olan
# satırları seçer ve  "Die Another Day" filmine ait verileri getirir.
# Out:
# Year                           2002
# Actor                Pierce Brosnan
# Director               Lee Tamahori
# Box Office                    465.4
# Budget                        154.2
# Bond Actor Salary              17.9
# Name: Die Another Day, dtype: object

# %%
james_bond.loc["Diamonds Are Forever" : "Moonraker"]
# bu iki film arasındaki indeks etiketine sahip satırları seçer.
# Out:
#                              Year         Actor       Director  Box Office  \
# Film
# Diamonds Are Forever         1971  Sean Connery   Guy Hamilton       442.5
# Live and Let Die             1973   Roger Moore   Guy Hamilton       460.3
# The Man with the Golden Gun  1974   Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977   Roger Moore  Lewis Gilbert       533.0
# Moonraker                    1979   Roger Moore  Lewis Gilbert       535.0
#
#                              Budget  Bond Actor Salary
# Film
# Diamonds Are Forever           34.7                5.8
# Live and Let Die               30.8                NaN
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN
# Moonraker                      91.5                NaN

# %%
james_bond.loc["Casino Royale" :" Live and Let Die" ]
# Out:
# Empty DataFrame
# Columns: [Year, Actor, Director, Box Office, Budget, Bond Actor Salary]
# Index: []

# %%
james_bond.sort_index(inplace=True)
james_bond
# .sort_index bu metot dataframein indekksini sıralar ve kalıcı olarak sıralar.
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
james_bond.loc["Casino Royale" :" Live and Let Die"]
# Out:
# Empty DataFrame
# Columns: [Year, Actor, Director, Box Office, Budget, Bond Actor Salary]
# Index: []

# %%
james_bond.loc["Casino Royale" :" Live and Let Die" : 2]
# bu iki film arasında 2satır atlayarak seçer.
# Out:
# Empty DataFrame
# Columns: [Year, Actor, Director, Box Office, Budget, Bond Actor Salary]
# Index: []

# %%
james_bond.loc["Casino Royale"][james_bond.loc["Casino Royale"].Year==1967]
#  "Casino Royale" filmine ait, ve aynı zamanda bu filmin yılı 1967
#  olan satırı seçer.
# Out:
#                Year        Actor    Director  Box Office  Budget  \
# Film
# Casino Royale  1967  David Niven  Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN

# %%
james_bond.iloc[0]
# bu filmiin ilk satırını seçer 0 yerine başka birşey kullanılsaydı başka
# satırı seçerdi (ilk satırın verilerinede ulaşabilirsiniz bu kodda)
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
james_bond.loc[["Casino Royale", "Goldfinger"], ["Year", "Budget"]]
# Burada "Casino Royale" ve "Goldfinger" filmlerine ait "year ve budge"
# sütunlarındaki verileri seçer
# Out:
#                Year  Budget
# Film
# Casino Royale  2006   145.3
# Casino Royale  1967    85.0
# Goldfinger     1964    18.6

# %%
james_bond.iloc[0:5,1:3]
# 0-5 arası satırları seçer (5 dahil değil) ve 1-3 arası sütunları seçer
# (3 dahil değil)
# Out:
#    Year         Actor
# 0  1962  Sean Connery
# 1  1963  Sean Connery
# 2  1964  Sean Connery
# 3  1965  Sean Connery
# 4  1967   David Niven
